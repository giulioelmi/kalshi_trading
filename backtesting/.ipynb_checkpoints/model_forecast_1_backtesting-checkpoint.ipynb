# %%
import pandas as pd

# %%
data = pd.read_csv("/content/training_data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1673 entries, 0 to 1672
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             1673 non-null   object
#  1   TMAX             1673 non-null   int64
#  2   TMIN             1673 non-null   int64
#  3   PRCP             1673 non-null   float64
#  4   AWND             1672 non-null   float64
#  5   WDF2             1673 non-null   float64
#  6   WSF2             1673 non-null   float64
#  7   year             1673 non-null   int64
#  8   forecasted_TMAX  1673 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 117.8+ KB

# %%
data["DATE"] = pd.to_datetime(data["DATE"])
data = data.sort_values("DATE")

# %%
data["TMAX_next_d"] = data["TMAX"].shift(-1)

# %%
data["y"] = data["TMAX_next_d"] - data["forecasted_TMAX"]

# %%
data["y"].hist()
# Out:
# <Axes: >

# %%
data[data["y"].abs() > 15]
# Out:
#            DATE  TMAX  TMIN  PRCP  AWND   WDF2  WSF2  year  forecasted_TMAX  \
# 106  2021-04-17    66    52  0.00  6.71  260.0  19.9  2021           66.200
# 286  2021-10-14    73    53  0.00  6.04  270.0  15.0  2021           69.260
# 298  2021-10-26    68    52  0.00  6.71  240.0  18.1  2021           64.220
# 313  2021-11-10    71    59  0.00  5.14  280.0  13.0  2021           67.910
# 323  2021-11-20    62    57  0.00  3.80  240.0  11.0  2021           62.330
# 372  2022-01-08    61    51  0.00  5.37  280.0  12.1  2022           59.846
# 460  2022-04-06    74    58  0.00  6.49  270.0  15.0  2022           79.898
# 477  2022-04-23    69    52  0.00  9.40  260.0  21.9  2022           67.712
# 615  2022-09-08    97    73  0.00  7.61  260.0  19.9  2022           84.452
# 655  2022-10-18    82    63  0.00  6.04  270.0  16.1  2022           77.846
# 1006 2023-10-04    81    60  0.00  6.49  260.0  17.0  2023           75.902
# 1343 2024-09-05    87    69  0.00  6.26  270.0  19.9  2024           84.758
# 1385 2024-10-17    70    62  0.00  6.49  280.0  15.0  2024           64.598
# 1401 2024-11-02    66    53  0.01  5.59  200.0  13.0  2024           62.492
#
#       TMAX_next_d       y
# 106          87.0  20.800
# 286          89.0  19.740
# 298          80.0  15.780
# 313          84.0  16.090
# 323          88.0  25.670
# 372          75.0  15.154
# 460          95.0  15.102
# 477          86.0  18.288
# 615         102.0  17.548
# 655          94.0  16.154
# 1006         91.0  15.098
# 1343        102.0  17.242
# 1385         84.0  19.402
# 1401         78.0  15.508

# %%
#feature engineering:
import numpy as np
#1. seasonality
data["doy"] = data["DATE"].dt.dayofyear
data["dow"] = data["DATE"].dt.dayofweek
data["month"] = data["DATE"].dt.month
data["doy_sin"] = np.sin(2*np.pi*data["doy"]/365.25)
data["doy_cos"] = np.cos(2*np.pi*data["doy"]/365.25)

# %%
#2 derived features
data["diurnal_range"] = data["TMAX"] - data["TMIN"]
data["wind_dir_sin"] = np.sin(np.deg2rad(data["WDF2"]))
data["wind_dir_cos"] = np.cos(np.deg2rad(data["WDF2"]))

# %%
#lag columns
lag_cols_1 = ["TMAX", "TMIN", "diurnal_range"]
for c in lag_cols_1:
    for k in [1, 2, 3, 7]:
            data[f"{c}_lag{k}"] = data[c].shift(k)

lag_cols_2 = ["PRCP"]
for k in [1, 2, 3, 4]:
    data[f"PRCP_lag_{k}"] = data["PRCP"].shift(k)

# %%
#rolling means
data["rolling_3"] = data["TMAX"].rolling(3).mean()
data["rolling_7"] = data["TMAX"].rolling(7).mean()

# %%
training_df = data.dropna()

# %%
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1664 entries, 7 to 1671
# Data columns (total 37 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATE                1664 non-null   datetime64[ns]
#  1   TMAX                1664 non-null   int64
#  2   TMIN                1664 non-null   int64
#  3   PRCP                1664 non-null   float64
#  4   AWND                1664 non-null   float64
#  5   WDF2                1664 non-null   float64
#  6   WSF2                1664 non-null   float64
#  7   year                1664 non-null   int64
#  8   forecasted_TMAX     1664 non-null   float64
#  9   TMAX_next_d         1664 non-null   float64
#  10  y                   1664 non-null   float64
#  11  doy                 1664 non-null   int32
#  12  dow                 1664 non-null   int32
#  13  month               1664 non-null   int32
#  14  doy_sin             1664 non-null   float64
#  15  doy_cos             1664 non-null   float64
#  16  diurnal_range       1664 non-null   int64
#  17  wind_dir_sin        1664 non-null   float64
#  18  wind_dir_cos        1664 non-null   float64
#  19  TMAX_lag1           1664 non-null   float64
#  20  TMAX_lag2           1664 non-null   float64
#  21  TMAX_lag3           1664 non-null   float64
#  22  TMAX_lag7           1664 non-null   float64
#  23  TMIN_lag1           1664 non-null   float64
#  24  TMIN_lag2           1664 non-null   float64
#  25  TMIN_lag3           1664 non-null   float64
#  26  TMIN_lag7           1664 non-null   float64
#  27  diurnal_range_lag1  1664 non-null   float64
#  28  diurnal_range_lag2  1664 non-null   float64
#  29  diurnal_range_lag3  1664 non-null   float64
#  30  diurnal_range_lag7  1664 non-null   float64
#  31  PRCP_lag_1          1664 non-null   float64
#  32  PRCP_lag_2          1664 non-null   float64
#  33  PRCP_lag_3          1664 non-null   float64
#  34  PRCP_lag_4          1664 non-null   float64
#  35  rolling_3           1664 non-null   float64
#  36  rolling_7           1664 non-null   float64
# dtypes: datetime64[ns](1), float64(29), int32(3), int64(4)
# memory usage: 474.5 KB

# %%
y = training_df["y"]
X = training_df.drop(columns = ["DATE", "y", "TMAX_next_d"])

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# X: features (sorted by date), y: target (next-day error)
tscv = TimeSeriesSplit(n_splits=5)

model = XGBRegressor(
    objective="reg:squarederror",
    eval_metric="mae",
    tree_method="hist",
    n_jobs=-1,
    random_state=42,
)

param_dist = {
    "n_estimators": [400, 800, 1200, 2000],
    "learning_rate": [0.01, 0.03, 0.05, 0.08],
    "max_depth": [2, 3, 4, 5, 6],
    "min_child_weight": [1, 3, 5, 8, 12],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0],
    "reg_lambda": [1, 5, 10, 20],
    "reg_alpha": [0.0, 0.01, 0.1],
}

search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=30,
    scoring="neg_mean_absolute_error",
    cv=tscv,
    verbose=1,
    random_state=42,
)

search.fit(X, y)

best_model = search.best_estimator_
best_mae = -search.best_score_

print("Best MAE:", best_mae)
print("Best params:", search.best_params_)

# Optional: baseline (predict 0 error)
baseline_mae = np.mean(np.abs(y))
print("Baseline MAE (predict 0):", baseline_mae)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best MAE: 3.064456666951385
# Best params: {'subsample': 1.0, 'reg_lambda': 20, 'reg_alpha': 0.0, 'n_estimators': 400, 'min_child_weight': 12, 'max_depth': 5, 'learning_rate': 0.01, 'colsample_bytree': 0.6}
# Baseline MAE (predict 0): 3.5031947115384514
